# %%
import os
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/messi2.jpg')
img.shape


img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert it to RGB format

plt.imshow(img_rgb)  # Display the image
plt.show()

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape

gray
# Out:
# array([[40, 40, 40, ..., 40, 41, 41],
#        [40, 40, 40, ..., 40, 40, 40],
#        [40, 40, 40, ..., 40, 40, 40],
#        ...,
#        [66, 57, 60, ..., 54, 45, 52],
#        [74, 60, 59, ..., 54, 62, 78],
#        [82, 63, 58, ..., 54, 51, 75]], dtype=uint8)

# %%
plt.imshow(gray, cmap= 'gray')  # Display the image
plt.show()

# %%
import cv2

# Use OpenCV's built-in haarcascades directory
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Read the image
img = cv2.imread('./test_images/messi2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces in the image
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(faces)
# Out:
# [[153  71 143 143]]

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (153, 71, 143, 143)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)
plt.show()

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img, (x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y: y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh), (0, 255,0), 2)

plt.figure()
plt.imshow(face_img, cmap = 'gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')
plt.show()

# %%
plt.show()

# %%
if roi_color is not None:
    cropped_img = np.array(roi_color)
    print(cropped_img.shape)
else:
    print("No valid cropped image")
# Out:
# No valid cropped image

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# ()

# %%
import cv2
import os

# Initialize face and eye cascades
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

def get_cropped_image_if_2_eyes(image_path):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image at {image_path}")
        return None
    
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    
    for (x, y, w, h) in faces:
        # Region of interest (ROI) for face
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        # Detect eyes in the face region
        eyes = eye_cascade.detectMultiScale(roi_gray)
        
        # If at least two eyes are detected, return the cropped face
        if len(eyes) >= 2:
            return roi_color

# Directory containing images
img_dir = "./model/datasets"

# Iterate through the directory and process each image file
for entry in os.scandir(img_dir):
    if entry.is_file():  # Ensure it's a file, not a directory
        print(f"Processing file: {entry.path}")
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            # Process the cropped image, save, etc.
            print(f"Processed image: {entry.path}")
# Out:
# Processing file: ./model/datasets/.DS_Store
# Error: Unable to load image at ./model/datasets/.DS_Store

# %%
original_image = cv2.imread('./test_images/messi2.jpg')
plt.imshow(original_image)
plt.show()

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/messi2.jpg')
plt.imshow(cropped_image)
plt.show()

# %%
path_to_data = "./model/datasets/"
path_to_cr_data = "./model/datasets/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./model/datasets/maria_sharapova',
#  './model/datasets/virat_kohli',
#  './model/datasets/lionel_messi',
#  './model/datasets/cropped',
#  './model/datasets/serena_williams',
#  './model/datasets/roger_federer']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
import os
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# Function to get cropped image if at least 2 eyes are detected
def get_cropped_image_if_2_eyes(image_path):
    # Read the image
    img = cv2.imread(image_path)
    if img is None:
        print(f"Error reading image {image_path}")
        return None

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        
        # Detect eyes
        eyes = eye_cascade.detectMultiScale(roi_gray)
        
        # If at least 2 eyes are detected, return the cropped face
        if len(eyes) >= 2:
            return roi_color

    return None

# Define paths
path_to_data = "./model/datasets/"
path_to_cr_data = "./model/datasets/cropped/"

# Initialize the dictionary to store file names for each celebrity
cropped_image_dirs = []
celebrity_file_name_dict = {}

# Get all directories in the dataset
img_dirs = [entry.path for entry in os.scandir(path_to_data) if entry.is_dir()]
print(f"Found directories to process: {img_dirs}")

# Iterate over directories containing celebrity images
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]  # Extract the celebrity name from the directory path
    print(f"Processing images for: {celebrity_name}")

    # Initialize the list for the celebrity if it doesn't exist
    if celebrity_name not in celebrity_file_name_dict:
        celebrity_file_name_dict[celebrity_name] = []

    # Iterate over the images in the directory
    for entry in os.scandir(img_dir):
        if entry.is_file():  # Ensure it's a file, not a directory
            image_path = entry.path
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            if roi_color is not None:
                # Define where to store the cropped images
                cropped_folder = os.path.join(path_to_cr_data, celebrity_name)
                
                # Create the folder if it doesn't exist
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    print(f"Creating folder for cropped images: {cropped_folder}")

                # Define the file name for the cropped image
                cropped_file_name = f"{celebrity_name}_{count}.png"
                cropped_file_path = os.path.join(cropped_folder, cropped_file_name)

                # Save the cropped image
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_name_dict[celebrity_name].append(cropped_file_path)
                count += 1

# After processing all images, you can print the dictionary to see the paths of cropped images
print(f"Cropped image paths: {celebrity_file_name_dict}")
# Out:
# Found directories to process: ['./model/datasets/maria_sharapova', './model/datasets/virat_kohli', './model/datasets/lionel_messi', './model/datasets/serena_williams', './model/datasets/roger_federer']
# Processing images for: maria_sharapova
# Creating folder for cropped images: ./model/datasets/cropped/maria_sharapova
# Error reading image ./model/datasets/maria_sharapova/yH5BAEKAAEALAAAAAABAAEAAAICTAEAOw==.gif
# Error reading image ./model/datasets/maria_sharapova/Google.svg
# Processing images for: virat_kohli
# Creating folder for cropped images: ./model/datasets/cropped/virat_kohli
# Error reading image ./model/datasets/virat_kohli/www.ipl.com.ico
# Error reading image ./model/datasets/virat_kohli/sports.ndtv.com.ico
# Error reading image ./model/datasets/virat_kohli/www.msn.com.ico
# Error reading image ./model/datasets/virat_kohli/facebook28px.svg
# Error reading image ./model/datasets/virat_kohli/www.indiatoday.in.ico
# ...

# %%
import os

path_to_cropped = "./model/datasets/cropped"  # Modify to the correct path
cropped_image_dirs = []

# Loop through subdirectories in the 'cropped' directory
for entry in os.scandir(path_to_cropped):
    if entry.is_dir():  # Only consider directories
        cropped_image_dirs.append(entry.path)

print("cropped_image_dirs populated:", cropped_image_dirs)
# Out:
# cropped_image_dirs populated: ['./model/datasets/cropped/maria_sharapova', './model/datasets/cropped/virat_kohli', './model/datasets/cropped/lionel_messi', './model/datasets/cropped/serena_williams', './model/datasets/cropped/roger_federer']

# %%
import os
import cv2
from PIL import Image

# Ensure the get_cropped_image_if_2_eyes() function is already defined properly
# It should return a cropped image with at least 2 eyes detected or None if not

# Define paths
path_to_data = "./model/datasets/"
path_to_cr_data = "./model/datasets/cropped/"

# Initialize the dictionary to store file names for each celebrity
celebrity_file_name_dict = {}

# Iterate over directories containing celebrity images
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]  # Extract the celebrity name from the directory path
    print(f"Processing images for: {celebrity_name}")

    # Initialize the list for the celebrity if it doesn't exist
    if celebrity_name not in celebrity_file_name_dict:
        celebrity_file_name_dict[celebrity_name] = []

    # Iterate over the images in the directory
    for entry in os.scandir(img_dir):
        if entry.is_file():  # Ensure it's a file, not a directory
            print(f"Processing file: {entry.path}")  # Debugging line to see files being processed
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            
            if roi_color is not None:
                print(f"Cropped image found for: {entry.path}")  # Debugging line to check if image is valid
                
                # Define where to store the cropped images
                cropped_folder = os.path.join(path_to_cr_data, celebrity_name)
                
                # Create the folder if it doesn't exist
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    print(f"Creating folder: {cropped_folder}")  # Debugging line to check folder creation

                # Define the file name for the cropped image
                cropped_file_name = f"{celebrity_name}_{count}.png"
                cropped_file_path = os.path.join(cropped_folder, cropped_file_name)

                # Save the cropped image
                roi_color_pil = Image.fromarray(roi_color)  # Convert from OpenCV to PIL
                roi_color_pil.info.pop('icc_profile', None)  # Remove ICC profile if present
                roi_color_pil.save(cropped_file_path)
                celebrity_file_name_dict[celebrity_name].append(cropped_file_path)

                print(f"Added cropped image to dictionary: {cropped_file_path}")  # Debugging line
                count += 1

# After processing all images, you can print the dictionary to see the paths of cropped images
print("Celebrity File Name Dictionary:", celebrity_file_name_dict)
# Out:
# Processing images for: maria_sharapova
# Processing file: ./model/datasets/maria_sharapova/BXFbL8ajtAhKAAAAAElFTkSuQmCC.png
# Processing file: ./model/datasets/maria_sharapova/www.usatoday.png
# Processing file: ./model/datasets/maria_sharapova/wXVwH0aAwAAAAASUVORK5CYII=.png
# Processing file: ./model/datasets/maria_sharapova/fIB1mABPKcJCAyAAAAAElFTkSuQmCC.png
# Processing file: ./model/datasets/maria_sharapova/www.thesportreview.png
# Processing file: ./model/datasets/maria_sharapova/www.tennis365.png
# Processing file: ./model/datasets/maria_sharapova/www.tatlerasia.png
# Processing file: ./model/datasets/maria_sharapova/maria sharapova ... (2).jpg
# Processing file: ./model/datasets/maria_sharapova/Maria Sharapova is Retiring_ A Look ....jpg
# Processing file: ./model/datasets/maria_sharapova/Maria Sharapova to be reinstated as UN ....jpg
# Processing file: ./model/datasets/maria_sharapova/Z (2).jpg
# Processing file: ./model/datasets/maria_sharapova/com_ (19).jpg
# ...

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    if img is None:
        raise ValueError("❌ Error: Input image is None. Check the image path or format.")

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

    # Normalize to [0,1] range
    imArray = np.float32(gray) / 255.0

    # Compute wavelet coefficients
    coeffs = pywt.wavedec2(imArray, mode, level=level)

    # Set approximation coefficients (LL) to zero
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0

    # Reconstruct the image
    imArray_H = pywt.waverec2(coeffs_H, mode)

    # Rescale to [0,255] and convert to uint8
    imArray_H = np.clip(imArray_H * 255, 0, 255).astype(np.uint8)

    # Ensure the output shape matches the input
    imArray_H = cv2.resize(imArray_H, (img.shape[1], img.shape[0]))

    return imArray_H

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'maria_sharapova': ['./model/datasets/cropped/maria_sharapova/maria_sharapova_28.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_14.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_15.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_29.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_17.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_16.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_12.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_13.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_11.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_10.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_8.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_9.png',
#   './model/datasets/cropped/maria_sharapova/maria_sharapova_1.png',
# ...

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'maria_sharapova': 0,
#  'virat_kohli': 1,
#  'lionel_messi': 2,
#  'serena_williams': 3,
#  'roger_federer': 4}

# %%
for training_image in training_files:
    print(f"Processing image: {training_image}")  # Debugging line to check image path
    
    # Check if the image exists
    if os.path.exists(training_image):
        img = cv2.imread(training_image)
        if img is None:
            print(f"Error: Failed to load image at {training_image}")
        else:
            # Image loaded successfully, resize it
            scalled_raw_img = cv2.resize(img, (32, 32))
            img_har = w2d(img, 'db1', 5)
            scalled_img_har = cv2.resize(img_har, (32, 32))
            combined_img = np.vstack((scalled_raw_img.reshape(32 * 32 * 3, 1), scalled_img_har.reshape(32 * 32, 1)))
            X.append(combined_img)
            y.append(class_dict[celebrity_name])
    else:
        print(f"Image file does not exist: {training_image}")
# Out:
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_33.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_27.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_26.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_32.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_18.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_24.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_30.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_31.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_25.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_19.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_21.png
# Processing image: ./model/datasets/cropped/lionel_messi/lionel_messi_35.png
# ...

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        
        # Ensure image was loaded correctly
        if img is None:
            print(f"Error: Failed to load image at {training_image}")
            continue

        # Resize to 32x32
        scalled_raw_img = cv2.resize(img, (32, 32))
        
        # Apply wavelet transform
        img_har = w2d(img, 'db1', 5)
        
        # Resize wavelet-transformed image
        scalled_img_har = cv2.resize(img_har, (32, 32))
        
        # Stack the raw and wavelet-transformed images
        combined_img = np.vstack((scalled_raw_img.reshape(32 * 32 * 3, 1), scalled_img_har.reshape(32 * 32, 1)))
        
        # Append combined image to X and label to y
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# Now X and y are populated with your data
# Out:
# Error: Failed to load image at ./model/datasets/cropped/lionel_messi/.DS_Store
# Error: Failed to load image at ./model/datasets/cropped/serena_williams/.DS_Store
# Error: Failed to load image at ./model/datasets/cropped/roger_federer/.DS_Store

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[11],
#        [15],
#        [17],
#        ...,
#        [ 0],
#        [ 0],
#        [13]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (160, 4096)

# %%
plt.imshow(img)
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.775

# %%
len(X_test)
# Out:
# 40

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       1.00      0.58      0.74        12
#            2       0.64      1.00      0.78         9
#            3       0.69      0.90      0.78        10
#            4       1.00      0.33      0.50         3
#
#     accuracy                           0.78        40
#    macro avg       0.87      0.73      0.74        40
# weighted avg       0.84      0.78      0.77        40

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.775

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.675

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.775

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[5, 0, 0, 1, 0],
#        [0, 8, 3, 1, 0],
#        [1, 0, 7, 1, 0],
#        [0, 0, 1, 9, 0],
#        [0, 0, 0, 1, 2]])

# %%
import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

plt.show()  # This will display the plot

# %%
class_dict
# Out:
# {'maria_sharapova': 0,
#  'virat_kohli': 1,
#  'lionel_messi': 2,
#  'serena_williams': 3,
#  'roger_federer': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ...
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
